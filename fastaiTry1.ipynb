# %%
from fastai.text import * 
import pandas as pd
import re 
import matplotlib.pyplot as plt

# %%
# Language model data
data_lm = TextLMDataBunch.from_csv(path, 'texts.csv')
# Classifier model data
data_clas = TextClasDataBunch.from_csv(path, 'texts.csv', vocab=data_lm.train_ds.vocab, bs=32)

# %%
# ~ Import packages ~ #
from google_patent_scrapper import scraper_class

# ~ Initialize scraper class ~ #
scraper=scraper_class() 

# ~~ Scrape patents individually ~~ #
patent_1 = 'US9389611B2'
patent_2 = 'US266827A'
err_1, soup_1, url_1 = scraper.request_single_patent(patent_1)
err_2, soup_2, url_2 = scraper.request_single_patent(patent_2)

# ~ Parse results of scrape ~ #
patent_1_parsed = scraper.get_scraped_data(soup_1,patent_1,url_1)
patent_2_parsed = scraper.get_scraped_data(soup_2,patent_2,url_2)
# Out:
# https://patents.google.com/patent/US9389611B2
# https://patents.google.com/patent/US266827A

# %%
soup_1
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>US9389611B2 - Adaptative platform for unmanned defense vehicles
#         - Google Patents</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta charset="utf-8"/>
# <meta content="origin-when-crossorigin" name="referrer"/>
# <link href="https://patents.google.com/patent/US9389611B2/en" rel="canonical"/>
# <meta content="
#      A kit for building an adaptive unmanned CIED vehicle comprising a vehicle chassis having a locomotion system for moving the vehicle in an operating environment, and a controllable steering mechanism for steering the vehicle as it moves in the operating environment; one or more motors for coupling to the locomotion system to the controllable steering mechanism; a remote control unit for communication with and for controlling the one or more motors and the controllable steering mechanism; payload devices for performing tasks attributed to the vehicle; and a platform for providing the capability of adapting the vehicle to perform new tasks in view of evolution in the operating environment, the platform comprising: a casing for mounting on or in the vehicle chassis; a computing device for connection to a selection of payload devices from the payload devices, and a memory for storing computing instructions for controlling operation of the selection of payload devices; a power source for powering at least one of the payload devices; power ports connected to the power source; and data ports connected to the computing device for connecting at least one of the payload devices to the computing device; wherein the computing device, the power source, the power ports and the data ports are mounted to the casing and wherein the payload devices and the one or more motors are for mounting to either the vehicle chassis or the casing. The payload devices are plug and play devices and are connected to the platform using standardized military connectors.
#
#    " name="description"/>
# <meta content="patent" name="DC.type"/>
# <meta content="Adaptative platform for unmanned defense vehicles
#        " name="DC.title"/>
# <meta content="2012-04-11" name="DC.date" scheme="dateSubmitted"/>
# <meta content="
#      A kit for building an adaptive unmanned CIED vehicle comprising a vehicle chassis having a locomotion system for moving the vehicle in an operating environment, and a controllable steering mechanism for steering the vehicle as it moves in the operating environment; one or more motors for coupling to the locomotion system to the controllable steering mechanism; a remote control unit for communication with and for controlling the one or more motors and the controllable steering mechanism; payload devices for performing tasks attributed to the vehicle; and a platform for providing the capability of adapting the vehicle to perform new tasks in view of evolution in the operating environment, the platform comprising: a casing for mounting on or in the vehicle chassis; a computing device for connection to a selection of payload devices from the payload devices, and a memory for storing computing instructions for controlling operation of the selection of payload devices; a power source for powering at least one of the payload devices; power ports connected to the power source; and data ports connected to the computing device for connecting at least one of the payload devices to the computing device; wherein the computing device, the power source, the power ports and the data ports are mounted to the casing and wherein the payload devices and the one or more motors are for mounting to either the vehicle chassis or the casing. The payload devices are plug and play devices and are connected to the platform using standardized military connectors.
#
#    " name="DC.description"/>
# <meta content="US:14/391,915" name="citation_patent_application_number"/>
# <meta content="https://patentimages.storage.googleapis.com/24/5c/8b/7e2975392b7be9/US9389611.pdf" name="citation_pdf_url"/>
# <meta content="US:9389611" name="citation_patent_number"/>
# <meta content="2016-07-12" name="DC.date" scheme="issue"/>
# <meta content="David Ryan ERICKSON" name="DC.contributor" scheme="inventor"/>
# <meta content="Matthew WJ CEH" name="DC.contributor" scheme="inventor"/>
# <meta content="Dale Anderson" name="DC.contributor" scheme="inventor"/>
# <meta content="Canada Minister of National Defence " name="DC.contributor" scheme="assignee"/>
# <meta content="US:4621562" name="DC.relation" scheme="references"/>
# <meta content="US:20040216932:A1" name="DC.relation" scheme="references"/>
# <meta content="US:20040168837:A1" name="DC.relation" scheme="references"/>
# <meta content="US:20060237239:A1" name="DC.relation" scheme="references"/>
# <meta content="US:20080017426:A1" name="DC.relation" scheme="references"/>
# <meta content="WO:2008060689:A2" name="DC.relation" scheme="references"/>
# <meta content="US:20100275472:A1" name="DC.relation" scheme="references"/>
# <meta content="US:20110190933:A1" name="DC.relation" scheme="references"/>
# <meta content="US:20110301786:A1" name="DC.relation" scheme="references"/>
# <meta content="International Search Report PCT/CA2012/000364." name="citation_reference" scheme="references"/>
# <meta content="IPRP-International Searching Authority, International Search Report, Jan. 25, 2013, 7p." name="citation_reference" scheme="references"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto:400,400italic,500,500italic,700" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Product+Sans" rel="stylesheet"/>
# <style>
#       body { transition: none; }
#     </style>
# <script>
#       (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#       (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#       m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#       })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#       ga('create', 'UA-27188110-4', 'auto');
#
#       version = 'patent-search.search_20200111_RC00';
#
#       function sendFeedback() {
#         userfeedback.api.startFeedback({
#           'productId': '713680',
#           'bucket': 'patent-search-web',
#           'productVersion': version,
#         });
#       }
#
#       window.experiments = {};
#       window.experiments.patentCountries = "ae,ag,al,am,ao,ap,ar,at,au,aw,az,ba,bb,bd,be,bf,bg,bh,bj,bn,bo,br,bw,bx,by,bz,ca,cf,cg,ch,ci,cl,cm,cn,co,cr,cs,cu,cy,cz,dd,de,dj,dk,dm,do,dz,ea,ec,ee,eg,em,ep,es,fi,fr,ga,gb,gc,gd,ge,gh,gm,gn,gq,gr,gt,gw,hk,hn,hr,hu,ib,id,ie,il,in,ir,is,it,jo,jp,ke,kg,kh,km,kn,kp,kr,kw,kz,la,lc,li,lk,lr,ls,lt,lu,lv,ly,ma,mc,md,me,mg,mk,ml,mn,mo,mr,mt,mw,mx,my,mz,na,ne,ng,ni,nl,no,nz,oa,om,pa,pe,pg,ph,pl,pt,py,qa,ro,rs,ru,rw,sa,sc,sd,se,sg,si,sk,sl,sm,sn,st,su,sv,sy,sz,td,tg,th,tj,tm,tn,tr,tt,tw,tz,ua,ug,us,uy,uz,vc,ve,vn,wo,yu,za,zm,zw";
#
#
#       window.profilePicture = "";
#
#       window.Polymer = {
#         dom: 'shady',
#         lazyRegister: true,
#       };
#     </script>
# <script src="//www.gstatic.com/patent-search/frontend/patent-search.search_20200111_RC00/scs/compiled_dir/webcomponentsjs/webcomponents-lite.min.js"></script>
# <link href="//www.gstatic.com/patent-search/frontend/patent-search.search_20200111_RC00/scs/compiled_dir/search-app-vulcanized.html" rel="import"/>
# </head>
# <body unresolved="">
# <script src="//www.gstatic.com/patent-search/frontend/patent-search.search_20200111_RC00/scs/compiled_dir/search-app-vulcanized.js"></script>
# <search-app>
# <article class="result" itemscope="" itemtype="http://schema.org/ScholarlyArticle">
# <h1 itemprop="pageTitle">US9389611B2 - Adaptative platform for unmanned defense vehicles
#         - Google Patents</h1>
# <span itemprop="title">Adaptative platform for unmanned defense vehicles
#        </span>
# <meta content="patent" itemprop="type"/>
# <a href="https://patentimages.storage.googleapis.com/24/5c/8b/7e2975392b7be9/US9389611.pdf" itemprop="pdfLink">Download PDF</a>
# <h2>Info</h2>
# <dl>
# <dt>Publication number</dt>
# <dd itemprop="publicationNumber">US9389611B2</dd>
# <meta content="9389611" itemprop="numberWithoutCodes"/>
# <meta content="B2" itemprop="kindCode"/>
# <meta content="Patent ( having previously published pre-grant publication)" itemprop="publicationDescription"/>
# <span>US9389611B2</span>
# <span>US14/391,915</span>
# <span>US201214391915A</span>
# <span>US9389611B2</span>
# <span>US 9389611 B2</span>
# <span>US9389611 B2</span>
# <span>US 9389611B2</span>
# <span> </span>
# <span> </span>
# <span> </span>
# <span>US 201214391915 A</span>
# <span>US201214391915 A</span>
# <span>US 201214391915A</span>
# <span>US 9389611 B2</span>
# <span>US9389611 B2</span>
# <span>US 9389611B2</span>
# <dt>Authority</dt>
# <dd itemprop="countryCode">US</dd>
# <dd itemprop="countryName">United States</dd>
# <dt>Prior art keywords</dt>
# <dd itemprop="priorArtKeywords" repeat="">vehicle</dd>
# <dd itemprop="priorArtKeywords" repeat="">ports</dd>
# <dd itemprop="priorArtKeywords" repeat="">platform</dd>
# <dd itemprop="priorArtKeywords" repeat="">payload devices</dd>
# <dd itemprop="priorArtKeywords" repeat="">chassis</dd>
# <dt>Prior art date</dt>
# <dd><time datetime="2012-04-11" itemprop="priorArtDate">2012-04-11</time></dd>
# <dt>Legal status (The legal status is an assumption and is not a legal conclusion. Google has not performed a legal analysis and makes no representation as to the accuracy of the status listed.)</dt>
# <dd itemprop="legalStatusIfi" itemscope="">
# <span itemprop="status">Active</span>
# </dd>
# </dl>
# <dt>Application number</dt>
# <dd itemprop="applicationNumber">US14/391,915</dd>
# <dt>Other versions</dt>
# <dd itemprop="directAssociations" itemscope="" repeat="">
# <a href="/patent/US20150301527A1/en">
# <span itemprop="publicationNumber">US20150301527A1</span>
#       (<span itemprop="primaryLanguage">en</span>
# </a>
# </dd>
# <dt>Inventor</dt>
# <dd itemprop="inventor" repeat="">David Ryan ERICKSON</dd>
# <dd itemprop="inventor" repeat="">Matthew WJ CEH</dd>
# <dd itemprop="inventor" repeat="">Dale Anderson</dd>
# <dt>Current Assignee (The listed assignees may be inaccurate. Google has not performed a legal analysis and makes no representation or warranty as to the accuracy of the list.)</dt>
# <dd itemprop="assigneeCurrent" repeat="">
#     Canada Minister of National Defence
#   </dd>
# <dt>Original Assignee</dt>
# <dd itemprop="assigneeOriginal" repeat="">Canada Minister of National Defence </dd>
# <dt>Priority date (The priority date is an assumption and is not a legal conclusion. Google has not performed a legal analysis and makes no representation as to the accuracy of the date listed.)</dt>
# <dd><time datetime="2012-04-11" itemprop="priorityDate">2012-04-11</time></dd>
# <dt>Filing date</dt>
# <dd><time datetime="2012-04-11" itemprop="filingDate">2012-04-11</time></dd>
# <dt>Publication date</dt>
# <dd><time datetime="2016-07-12" itemprop="publicationDate">2016-07-12</time></dd>
# <dd itemprop="events" itemscope="" repeat="">
# <time datetime="2012-04-11" itemprop="date">2012-04-11</time>
# <span itemprop="title">Application filed by Canada Minister of National Defence </span>
# <span itemprop="type">filed</span>
# <span bool="" content="true" itemprop="critical">Critical</span>
# <span itemprop="assigneeSearch">Canada Minister of National Defence </span>
# </dd>
# <dd itemprop="events" itemscope="" repeat="">
# <time datetime="2012-04-11" itemprop="date">2012-04-11</time>
# <span itemprop="title">Priority to PCT/CA2012/000364</span>
# <span itemprop="type">priority</span>
# <span bool="" content="true" itemprop="critical">Critical</span>
# <span itemprop="documentId">patent/WO2013152414A1/en</span>
# </dd>
# <dd itemprop="events" itemscope="" repeat="">
# <time datetime="2014-12-10" itemprop="date">2014-12-10</time>
# <span itemprop="title">Assigned to HER MAJESTY THE QUEEN IN RIGHT OF CANADA AS REPRESENTED BY THE MINISTER OF NATIONAL DEFENCE</span>
# <span itemprop="type">reassignment</span>
# <span itemprop="assigneeSearch">HER MAJESTY THE QUEEN IN RIGHT OF CANADA AS REPRESENTED BY THE MINISTER OF NATIONAL DEFENCE</span>
# <span itemprop="description" repeat="">ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT FOR DETAILS).</span>
# <span itemprop="description" repeat="">Assignors: ANDERSON, DALE, ERICKSON, David Ryan, CEH, Matthew WJ</span>
# </dd>
# <dd itemprop="events" itemscope="" repeat="">
# <time datetime="2015-10-22" itemprop="date">2015-10-22</time>
# <span itemprop="title">Publication of US20150301527A1</span>
# <span itemprop="type">publication</span>
# <span bool="" content="true" itemprop="critical">Critical</span>
# <span itemprop="documentId">patent/US20150301527A1/en</span>
# </dd>
# <dd itemprop="events" itemscope="" repeat="">
# <time datetime="2016-07-12" itemprop="date">2016-07-12</time>
# <span itemprop="title">Application granted</span>
# <span itemprop="type">granted</span>
# <span bool="" content="true" itemprop="critical">Critical</span>
# </dd>
# <dd itemprop="events" itemscope="" repeat="">
# <time datetime="2016-07-12" itemprop="date">2016-07-12</time>
# <span itemprop="title">Publication of US9389611B2</span>
# <span itemprop="type">publication</span>
# <span bool="" content="true" itemprop="critical">Critical</span>
# <span itemprop="documentId">patent/US9389611B2/en</span>
# </dd>
# <dd itemprop="events" itemscope="" repeat="">
# <time datetime="2020-02-04" itemprop="date">2020-02-04</time>
# <span itemprop="title">Application status is Active</span>
# <span itemprop="type">legal-status</span>
# <span bool="" content="true" itemprop="critical">Critical</span>
# </dd>
# <dd itemprop="events" itemscope="" repeat="">
# <time datetime="2032-04-11" itemprop="date">2032-04-11</time>
# <span itemprop="title">Anticipated expiration</span>
# <span itemprop="type">legal-status</span>
# <span bool="" content="true" itemprop="critical">Critical</span>
# </dd>
# <h2>Links</h2>
# <ul>
# <li itemprop="links" itemscope="" repeat="">
# <meta content="usptoLink" itemprop="id"/>
# <a href="http://patft.uspto.gov/netacgi/nph-Parser?Sect1=PTO1&amp;Sect2=HITOFF&amp;p=1&amp;u=/netahtml/PTO/srchnum.html&amp;r=1&amp;f=G&amp;l=50&amp;d=PALL&amp;s1=9389611.PN." itemprop="url" target="_blank"><span itemprop="text">USPTO</span></a>
# </li>
# <li itemprop="links" itemscope="" repeat="">
# <meta content="usptoAssignmentLink" itemprop="id"/>
# <a href="https://assignment.uspto.gov/patent/index.html#/patent/search/resultFilter?searchInput=9389611" itemprop="url" target="_blank"><span itemprop="text">USPTO Assignment</span></a>
# </li>
# <li itemprop="links" itemscope="" repeat="">
# <meta content="espacenetLink" itemprop="id"/>
# <a href="http://worldwide.espacenet.com/publicationDetails/biblio?CC=US&amp;NR=9389611B2&amp;KC=B2&amp;FT=D" itemprop="url" target="_blank"><span itemprop="text">Espacenet</span></a>
# </li>
# <li itemprop="links" itemscope="" repeat="">
# <meta content="globalDossierLink" itemprop="id"/>
# <a href="http://globaldossier.uspto.gov/#/result/patent/US/9389611/1" itemprop="url" target="_blank"><span itemprop="text">Global Dossier</span></a>
# </li>
# <li itemprop="links" itemscope="" repeat="">
# <meta content="stackexchangeLink" itemprop="id"/>
# <a href="https://patents.stackexchange.com/questions/tagged/US9389611" itemprop="url"><span itemprop="text">Discuss</span></a>
# </li>
# </ul>
# <ul itemprop="concept" itemscope="">
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">238000004891</span>
# <span itemprop="name">communication</span>
# <span itemprop="domain">Methods</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">abstract</span>
# <span itemprop="sections" repeat="">claims</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">25</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">230000033001</span>
# <span itemprop="name">locomotion</span>
# <span itemprop="domain">Effects</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">abstract</span>
# <span itemprop="sections" repeat="">claims</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">25</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">230000015654</span>
# <span itemprop="name">memory</span>
# <span itemprop="domain">Effects</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">abstract</span>
# <span itemprop="sections" repeat="">claims</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">25</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">230000001276</span>
# <span itemprop="name">controlling effects</span>
# <span itemprop="domain">Effects</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">abstract</span>
# <span itemprop="sections" repeat="">claims</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">19</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">230000003044</span>
# <span itemprop="name">adaptive</span>
# <span itemprop="domain">Effects</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">abstract</span>
# <span itemprop="sections" repeat="">claims</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">9</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">230000001808</span>
# <span itemprop="name">coupling</span>
# <span itemprop="domain">Effects</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">abstract</span>
# <span itemprop="sections" repeat="">claims</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">7</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">238000010168</span>
# <span itemprop="name">coupling process</span>
# <span itemprop="domain">Methods</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">abstract</span>
# <span itemprop="sections" repeat="">claims</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">7</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">238000005859</span>
# <span itemprop="name">coupling reaction</span>
# <span itemprop="domain">Methods</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">abstract</span>
# <span itemprop="sections" repeat="">claims</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">7</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">239000002360</span>
# <span itemprop="name">explosive</span>
# <span itemprop="domain">Substances</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">claims</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">11</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">230000000051</span>
# <span itemprop="name">modifying</span>
# <span itemprop="domain">Effects</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">claims</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">6</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">239000003570</span>
# <span itemprop="name">air</span>
# <span itemprop="domain">Substances</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">claims</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">5</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">238000003860</span>
# <span itemprop="name">storage</span>
# <span itemprop="domain">Methods</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">claims</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">4</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">239000004793</span>
# <span itemprop="name">Polystyrene</span>
# <span itemprop="domain">Substances</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">claims</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">3</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">239000000969</span>
# <span itemprop="name">carrier</span>
# <span itemprop="domain">Substances</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">claims</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">3</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">238000002485</span>
# <span itemprop="name">combustion</span>
# <span itemprop="domain">Methods</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">claims</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">3</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">238000009740</span>
# <span itemprop="name">moulding (composite fabrication)</span>
# <span itemprop="domain">Methods</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">claims</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">2</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">230000004048</span>
# <span itemprop="name">modification</span>
# <span itemprop="domain">Effects</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">16</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">238000006011</span>
# <span itemprop="name">modification</span>
# <span itemprop="domain">Methods</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">16</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">230000000875</span>
# <span itemprop="name">corresponding</span>
# <span itemprop="domain">Effects</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">8</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">238000000034</span>
# <span itemprop="name">methods</span>
# <span itemprop="domain">Methods</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">3</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">238000004422</span>
# <span itemprop="name">calculation algorithm</span>
# <span itemprop="domain">Methods</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">2</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">239000000203</span>
# <span itemprop="name">mixtures</span>
# <span itemprop="domain">Substances</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">2</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">230000001133</span>
# <span itemprop="name">acceleration</span>
# <span itemprop="domain">Effects</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">1</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">238000007792</span>
# <span itemprop="name">addition</span>
# <span itemprop="domain">Methods</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">1</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">239000004452</span>
# <span itemprop="name">animal feeding substances</span>
# <span itemprop="domain">Substances</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">1</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">239000011162</span>
# <span itemprop="name">core materials</span>
# <span itemprop="domain">Substances</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">1</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">230000001419</span>
# <span itemprop="name">dependent</span>
# <span itemprop="domain">Effects</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">1</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">230000018109</span>
# <span itemprop="name">developmental process</span>
# <span itemprop="domain">Effects</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">1</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">238000005516</span>
# <span itemprop="name">engineering processes</span>
# <span itemprop="domain">Methods</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">1</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">230000035611</span>
# <span itemprop="name">feeding</span>
# <span itemprop="domain">Effects</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">1</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">230000000670</span>
# <span itemprop="name">limiting</span>
# <span itemprop="domain">Effects</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">1</span>
# </li>
# <li itemprop="match" itemscope="" repeat="">
# <span itemprop="id">238000007514</span>
# <span itemprop="name">turning</span>
# <span itemprop="domain">Methods</span>
# <span itemprop="svg_large"></span>
# <span itemprop="svg_small"></span>
# <span itemprop="smiles"></span>
# <span itemprop="inchi_key"></span>
# <span itemprop="similarity">0</span>
# <span itemprop="sections" repeat="">description</span>
# <span itemprop="count">1</span>
# </li>
# </ul>
# <section>
# <h2>Images</h2>
# <ul>
# <li itemprop="images" itemscope="" repeat="">
# <img itemprop="thumbnail" src="https://patentimages.storage.googleapis.com/db/f4/56/a57a35b395633e/US09389611-20160712-D00000.png"/>
# <meta content="https://patentimages.storage.googleapis.com/83/47/1e/e61f8b7fff5c67/US09389611-20160712-D00000.png" itemprop="full"/>
# <ul>
# <li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="200" itemprop="id"/>
# <meta content="platform" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="2918" itemprop="left"/>
# <meta content="1237" itemprop="top"/>
# <meta content="3050" itemprop="right"/>
# <meta content="1300" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="200" itemprop="id"/>
# <meta content="platform" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1032" itemprop="left"/>
# <meta content="1130" itemprop="top"/>
# <meta content="1166" itemprop="right"/>
# <meta content="1192" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="206" itemprop="id"/>
# <meta content="motor" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="3892" itemprop="left"/>
# <meta content="1671" itemprop="top"/>
# <meta content="4017" itemprop="right"/>
# <meta content="1735" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="206" itemprop="id"/>
# <meta content="motor" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1032" itemprop="left"/>
# <meta content="575" itemprop="top"/>
# <meta content="1155" itemprop="right"/>
# <meta content="637" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="210" itemprop="id"/>
# <meta content="power ports" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="3228" itemprop="left"/>
# <meta content="1714" itemprop="top"/>
# <meta content="3357" itemprop="right"/>
# <meta content="1775" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="210" itemprop="id"/>
# <meta content="power ports" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1567" itemprop="left"/>
# <meta content="934" itemprop="top"/>
# <meta content="1698" itemprop="right"/>
# <meta content="996" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="212" itemprop="id"/>
# <meta content="data ports" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="3518" itemprop="left"/>
# <meta content="1714" itemprop="top"/>
# <meta content="3647" itemprop="right"/>
# <meta content="1774" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="212" itemprop="id"/>
# <meta content="data ports" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1568" itemprop="left"/>
# <meta content="741" itemprop="top"/>
# <meta content="1690" itemprop="right"/>
# <meta content="804" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="216" itemprop="id"/>
# <meta content="connectors" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1072" itemprop="left"/>
# <meta content="814" itemprop="top"/>
# <meta content="1196" itemprop="right"/>
# <meta content="877" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="218" itemprop="id"/>
# <meta content="rotation shaft coupling" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1033" itemprop="left"/>
# <meta content="496" itemprop="top"/>
# <meta content="1154" itemprop="right"/>
# <meta content="558" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="250" itemprop="id"/>
# <meta content="body" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="2081" itemprop="left"/>
# <meta content="492" itemprop="top"/>
# <meta content="2217" itemprop="right"/>
# <meta content="555" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="252" itemprop="id"/>
# <meta content="transmission" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1639" itemprop="left"/>
# <meta content="494" itemprop="top"/>
# <meta content="1765" itemprop="right"/>
# <meta content="557" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="254" itemprop="id"/>
# <meta content="turbine" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1843" itemprop="left"/>
# <meta content="179" itemprop="top"/>
# <meta content="1967" itemprop="right"/>
# <meta content="242" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="256" itemprop="id"/>
# <meta content="steering mechanism" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1640" itemprop="left"/>
# <meta content="1564" itemprop="top"/>
# <meta content="1766" itemprop="right"/>
# <meta content="1629" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="258" itemprop="id"/>
# <meta content="data cable" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1640" itemprop="left"/>
# <meta content="1445" itemprop="top"/>
# <meta content="1766" itemprop="right"/>
# <meta content="1509" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="280" itemprop="id"/>
# <meta content="body" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="3284" itemprop="left"/>
# <meta content="1237" itemprop="top"/>
# <meta content="3415" itemprop="right"/>
# <meta content="1299" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="281" itemprop="id"/>
# <meta content="unmanned submarine" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="2235" itemprop="left"/>
# <meta content="1080" itemprop="top"/>
# <meta content="2362" itemprop="right"/>
# <meta content="1143" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="282" itemprop="id"/>
# <meta content="transmission" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="4141" itemprop="left"/>
# <meta content="1670" itemprop="top"/>
# <meta content="4270" itemprop="right"/>
# <meta content="1734" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="284" itemprop="id"/>
# <meta content="turbine" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="4382" itemprop="left"/>
# <meta content="1235" itemprop="top"/>
# <meta content="4504" itemprop="right"/>
# <meta content="1298" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="286" itemprop="id"/>
# <meta content="fins" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="4460" itemprop="left"/>
# <meta content="1671" itemprop="top"/>
# <meta content="4588" itemprop="right"/>
# <meta content="1736" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="288" itemprop="id"/>
# <meta content="cable" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="4091" itemprop="left"/>
# <meta content="1231" itemprop="top"/>
# <meta content="4220" itemprop="right"/>
# <meta content="1296" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="290" itemprop="id"/>
# <meta content="sonar transceiver" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="2832" itemprop="left"/>
# <meta content="1076" itemprop="top"/>
# <meta content="2965" itemprop="right"/>
# <meta content="1151" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="0" itemprop="figurePage"/>
# <meta content="292" itemprop="id"/>
# <meta content="cable" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="2759" itemprop="left"/>
# <meta content="1677" itemprop="top"/>
# <meta content="2920" itemprop="right"/>
# <meta content="1739" itemprop="bottom"/>
# </span>
# </li>
# </ul>
# </li>
# <li itemprop="images" itemscope="" repeat="">
# <img itemprop="thumbnail" src="https://patentimages.storage.googleapis.com/b7/ef/5d/6ed381df5769fb/US09389611-20160712-D00001.png"/>
# <meta content="https://patentimages.storage.googleapis.com/8c/a2/bf/2cd8bc80f418ca/US09389611-20160712-D00001.png" itemprop="full"/>
# <ul>
# <li itemprop="callouts" itemscope="" repeat="">
# <meta content="1" itemprop="figurePage"/>
# <meta content="202" itemprop="id"/>
# <meta content="communication link" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="589" itemprop="left"/>
# <meta content="1859" itemprop="top"/>
# <meta content="659" itemprop="right"/>
# <meta content="1973" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="1" itemprop="figurePage"/>
# <meta content="204" itemprop="id"/>
# <meta content="computing device" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="603" itemprop="left"/>
# <meta content="1215" itemprop="top"/>
# <meta content="676" itemprop="right"/>
# <meta content="1328" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="1" itemprop="figurePage"/>
# <meta content="206" itemprop="id"/>
# <meta content="motor" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1022" itemprop="left"/>
# <meta content="1213" itemprop="top"/>
# <meta content="1087" itemprop="right"/>
# <meta content="1331" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="1" itemprop="figurePage"/>
# <meta content="208" itemprop="id"/>
# <meta content="power source" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1080" itemprop="left"/>
# <meta content="1859" itemprop="top"/>
# <meta content="1151" itemprop="right"/>
# <meta content="1974" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="1" itemprop="figurePage"/>
# <meta content="212" itemprop="id"/>
# <meta content="data ports" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="601" itemprop="left"/>
# <meta content="579" itemprop="top"/>
# <meta content="672" itemprop="right"/>
# <meta content="709" itemprop="bottom"/>
# </span>
# </li>
# </ul>
# </li>
# <li itemprop="images" itemscope="" repeat="">
# <img itemprop="thumbnail" src="https://patentimages.storage.googleapis.com/dd/89/26/459c65aee8d19f/US09389611-20160712-D00002.png"/>
# <meta content="https://patentimages.storage.googleapis.com/69/0c/f3/74804effd88745/US09389611-20160712-D00002.png" itemprop="full"/>
# <ul>
# <li itemprop="callouts" itemscope="" repeat="">
# <meta content="2" itemprop="figurePage"/>
# <meta content="200" itemprop="id"/>
# <meta content="platform" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="238" itemprop="left"/>
# <meta content="2149" itemprop="top"/>
# <meta content="302" itemprop="right"/>
# <meta content="2281" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="2" itemprop="figurePage"/>
# <meta content="206" itemprop="id"/>
# <meta content="motor" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="916" itemprop="left"/>
# <meta content="336" itemprop="top"/>
# <meta content="984" itemprop="right"/>
# <meta content="445" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="2" itemprop="figurePage"/>
# <meta content="212" itemprop="id"/>
# <meta content="data ports" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1462" itemprop="left"/>
# <meta content="1359" itemprop="top"/>
# <meta content="1530" itemprop="right"/>
# <meta content="1479" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="2" itemprop="figurePage"/>
# <meta content="214" itemprop="id"/>
# <meta content="casing" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="591" itemprop="left"/>
# <meta content="330" itemprop="top"/>
# <meta content="658" itemprop="right"/>
# <meta content="472" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="2" itemprop="figurePage"/>
# <meta content="216" itemprop="id"/>
# <meta content="connectors" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="518" itemprop="left"/>
# <meta content="1100" itemprop="top"/>
# <meta content="585" itemprop="right"/>
# <meta content="1217" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="2" itemprop="figurePage"/>
# <meta content="218" itemprop="id"/>
# <meta content="rotation shaft coupling" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1029" itemprop="left"/>
# <meta content="331" itemprop="top"/>
# <meta content="1094" itemprop="right"/>
# <meta content="489" itemprop="bottom"/>
# </span>
# </li>
# </ul>
# </li>
# <li itemprop="images" itemscope="" repeat="">
# <img itemprop="thumbnail" src="https://patentimages.storage.googleapis.com/97/cd/c0/b52839af9dcd4c/US09389611-20160712-D00003.png"/>
# <meta content="https://patentimages.storage.googleapis.com/fb/9d/0c/b95e262a812484/US09389611-20160712-D00003.png" itemprop="full"/>
# <ul>
# <li itemprop="callouts" itemscope="" repeat="">
# <meta content="3" itemprop="figurePage"/>
# <meta content="230" itemprop="id"/>
# <meta content="vehicle chassis" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1258" itemprop="left"/>
# <meta content="227" itemprop="top"/>
# <meta content="1326" itemprop="right"/>
# <meta content="338" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="3" itemprop="figurePage"/>
# <meta content="232" itemprop="id"/>
# <meta content="wheels" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="204" itemprop="left"/>
# <meta content="1261" itemprop="top"/>
# <meta content="269" itemprop="right"/>
# <meta content="1393" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="3" itemprop="figurePage"/>
# <meta content="232" itemprop="id"/>
# <meta content="wheels" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1872" itemprop="left"/>
# <meta content="1233" itemprop="top"/>
# <meta content="1940" itemprop="right"/>
# <meta content="1389" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="3" itemprop="figurePage"/>
# <meta content="234" itemprop="id"/>
# <meta content="transmission" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="785" itemprop="left"/>
# <meta content="235" itemprop="top"/>
# <meta content="854" itemprop="right"/>
# <meta content="346" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="3" itemprop="figurePage"/>
# <meta content="236" itemprop="id"/>
# <meta content="controllable steering mechanism" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="812" itemprop="left"/>
# <meta content="2211" itemprop="top"/>
# <meta content="879" itemprop="right"/>
# <meta content="2320" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="3" itemprop="figurePage"/>
# <meta content="238" itemprop="id"/>
# <meta content="power cable" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1514" itemprop="left"/>
# <meta content="1401" itemprop="top"/>
# <meta content="1582" itemprop="right"/>
# <meta content="1534" itemprop="bottom"/>
# </span>
# </li>
# </ul>
# </li>
# <li itemprop="images" itemscope="" repeat="">
# <img itemprop="thumbnail" src="https://patentimages.storage.googleapis.com/a1/df/8b/fcf7505f110dd8/US09389611-20160712-D00004.png"/>
# <meta content="https://patentimages.storage.googleapis.com/c7/e5/f1/e45227862ca298/US09389611-20160712-D00004.png" itemprop="full"/>
# <ul>
# <li itemprop="callouts" itemscope="" repeat="">
# <meta content="4" itemprop="figurePage"/>
# <meta content="210" itemprop="id"/>
# <meta content="power ports" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1400" itemprop="left"/>
# <meta content="1511" itemprop="top"/>
# <meta content="1462" itemprop="right"/>
# <meta content="1639" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# <meta content="4" itemprop="figurePage"/>
# <meta content="212" itemprop="id"/>
# <meta content="data ports" itemprop="label"/>
# <span itemprop="bounds" itemscope="">
# <meta content="1398" itemprop="left"/>
# <meta content="1103" itemprop="top"/>
# <meta content="1463" itemprop="right"/>
# <meta content="1222" itemprop="bottom"/>
# </span>
# </li><li itemprop="callouts" itemscope="" repeat="">
# ...
# <td itemprop="title">Remote Vehicle Control System and Method
#        </td>
# </tr>
# </tbody>
# </table>
# </section>
# <section>
# <h2>Non-Patent Citations (2)</h2>
# <table>
# <caption>* Cited by examiner, † Cited by third party</caption>
# <thead>
# <tr>
# <th>Title</th>
# </tr>
# </thead>
# <tbody>
# <tr itemprop="detailedNonPatentLiterature" itemscope="" repeat="">
# <td>
# <span itemprop="title">International Search Report PCT/CA2012/000364.</span>
# </td>
# </tr><tr itemprop="detailedNonPatentLiterature" itemscope="" repeat="">
# <td>
# <span itemprop="title">IPRP-International Searching Authority, International Search Report, Jan. 25, 2013, 7p.</span>
# </td>
# </tr>
# </tbody>
# </table>
# </section>
# <h2>Cited By (1)</h2>
# <table>
# <caption>* Cited by examiner, † Cited by third party</caption>
# <thead>
# <tr>
# <th>Publication number</th>
# <th>Priority date</th>
# <th>Publication date</th>
# <th>Assignee</th>
# <th>Title</th>
# </tr>
# </thead>
# <tbody>
# <tr itemprop="forwardReferences" itemscope="" repeat="">
# <td>
# <a href="/patent/US20170168810A1/en">
# <span itemprop="publicationNumber">US20170168810A1</span>
#             (<span itemprop="primaryLanguage">en</span>)
#           </a>
# <span itemprop="examinerCited">*</span>
# </td>
# <td itemprop="priorityDate">2015-12-11</td>
# <td itemprop="publicationDate">2017-06-15</td>
# <td><span itemprop="assigneeOriginal">Airbus Operations Gmbh</span></td>
# <td itemprop="title">Technique for updating software on board an aircraft
#        </td>
# </tr>
# </tbody>
# </table>
# <section>
# <h2>Also Published As</h2>
# <table>
# <thead>
# <tr>
# <th>Publication number</th>
# <th>Publication date</th>
# </tr>
# </thead>
# <tbody>
# <tr itemprop="docdbFamily" itemscope="" repeat="">
# <td>
# <a href="/patent/CA2870072C/en">
# <span itemprop="publicationNumber">CA2870072C</span>
#               (<span itemprop="primaryLanguage">en</span>)
#             </a>
# </td>
# <td itemprop="publicationDate">2019-05-28</td>
# </tr><tr itemprop="docdbFamily" itemscope="" repeat="">
# <td>
# <a href="/patent/US20150301527A1/en">
# <span itemprop="publicationNumber">US20150301527A1</span>
#               (<span itemprop="primaryLanguage">en</span>)
#             </a>
# </td>
# <td itemprop="publicationDate">2015-10-22</td>
# </tr><tr itemprop="docdbFamily" itemscope="" repeat="">
# <td>
# <a href="/patent/CA2870072A1/en">
# <span itemprop="publicationNumber">CA2870072A1</span>
#               (<span itemprop="primaryLanguage">en</span>)
#             </a>
# </td>
# <td itemprop="publicationDate">2013-10-17</td>
# </tr><tr itemprop="docdbFamily" itemscope="" repeat="">
# <td>
# <a href="/patent/WO2013152414A1/en">
# <span itemprop="publicationNumber">WO2013152414A1</span>
#               (<span itemprop="primaryLanguage">en</span>)
#             </a>
# </td>
# <td itemprop="publicationDate">2013-10-17</td>
# </tr>
# </tbody>
# </table>
# </section>
# <section>
# <h2>Similar Documents</h2>
# <table>
# <thead>
# <tr>
# <th>Publication</th>
# <th>Publication Date</th>
# <th>Title</th>
# </tr>
# </thead>
# <tbody>
# <tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isScholar"/>
# <meta content="14499410798635034369" itemprop="scholarID"/>
# <a href="/scholar/14499410798635034369"><span itemprop="scholarAuthors">Binnendijk</span></a>
# </td>
# <td>
# <time datetime="2002" itemprop="publicationDate">2002</time>
# </td>
# <td itemprop="title">Transforming America's military</td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isScholar"/>
# <meta content="3841776122340024622" itemprop="scholarID"/>
# <a href="/scholar/3841776122340024622"><span itemprop="scholarAuthors">Gundlach</span></a>
# </td>
# <td>
# <time datetime="2012" itemprop="publicationDate">2012</time>
# </td>
# <td itemprop="title">Designing unmanned aircraft systems: a comprehensive approach</td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/US6945780B2/en">
# <span itemprop="publicationNumber">US6945780B2</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2005-09-20" itemprop="publicationDate">2005-09-20</time>
# </td>
# <td itemprop="title">Integrated performance simulation system for military weapon systems
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/US6598828B2/en">
# <span itemprop="publicationNumber">US6598828B2</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2003-07-29" itemprop="publicationDate">2003-07-29</time>
# </td>
# <td itemprop="title">Integral data acquisition capacity
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/US5340056A/en">
# <span itemprop="publicationNumber">US5340056A</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="1994-08-23" itemprop="publicationDate">1994-08-23</time>
# </td>
# <td itemprop="title">Active defense system against tactical ballistic missiles
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/EP2780869B1/en">
# <span itemprop="publicationNumber">EP2780869B1</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2019-03-13" itemprop="publicationDate">2019-03-13</time>
# </td>
# <td itemprop="title">System and associated method of controlling range and payload for unmanned aerial vehicles
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/US7047861B2/en">
# <span itemprop="publicationNumber">US7047861B2</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2006-05-23" itemprop="publicationDate">2006-05-23</time>
# </td>
# <td itemprop="title">System, methods and apparatus for managing a weapon system
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/AU2006306522B2/en">
# <span itemprop="publicationNumber">AU2006306522B2</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2011-07-28" itemprop="publicationDate">2011-07-28</time>
# </td>
# <td itemprop="title">Networked multi-role robotic vehicle
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/US20120209456A1/en">
# <span itemprop="publicationNumber">US20120209456A1</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2012-08-16" itemprop="publicationDate">2012-08-16</time>
# </td>
# <td itemprop="title">Parallel Hybrid-Electric Propulsion Systems for Unmanned Aircraft
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/JP2007500094A/en">
# <span itemprop="publicationNumber">JP2007500094A</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2007-01-11" itemprop="publicationDate">2007-01-11</time>
# </td>
# <td itemprop="title">Contact airliner defense (CAD) system
#      </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/US20160364989A1/en">
# <span itemprop="publicationNumber">US20160364989A1</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2016-12-15" itemprop="publicationDate">2016-12-15</time>
# </td>
# <td itemprop="title">Unmanned aerial vehicle management
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/US20160129999A1/en">
# <span itemprop="publicationNumber">US20160129999A1</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2016-05-12" itemprop="publicationDate">2016-05-12</time>
# </td>
# <td itemprop="title">Drone systems for pre-trip inspection and assisted backing
#      </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/US20040030570A1/en">
# <span itemprop="publicationNumber">US20040030570A1</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2004-02-12" itemprop="publicationDate">2004-02-12</time>
# </td>
# <td itemprop="title">System, methods and apparatus for leader-follower model of mobile robotic system aggregation
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isScholar"/>
# <meta content="16206013062506423142" itemprop="scholarID"/>
# <a href="/scholar/16206013062506423142"><span itemprop="scholarAuthors">Johnson et al.</span></a>
# </td>
# <td>
# <time datetime="2003" itemprop="publicationDate">2003</time>
# </td>
# <td itemprop="title">The Georgia Tech unmanned aerial research vehicle: GTMax</td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/US20040030571A1/en">
# <span itemprop="publicationNumber">US20040030571A1</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2004-02-12" itemprop="publicationDate">2004-02-12</time>
# </td>
# <td itemprop="title">System, method and apparatus for automated collective mobile robotic vehicles used in remote sensing surveillance
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/US20040068415A1/en">
# <span itemprop="publicationNumber">US20040068415A1</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2004-04-08" itemprop="publicationDate">2004-04-08</time>
# </td>
# <td itemprop="title">System, methods and apparatus for coordination of and targeting for mobile robotic vehicles
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/US20040068416A1/en">
# <span itemprop="publicationNumber">US20040068416A1</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2004-04-08" itemprop="publicationDate">2004-04-08</time>
# </td>
# <td itemprop="title">System, method and apparatus for implementing a mobile sensor network
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/US20040030448A1/en">
# <span itemprop="publicationNumber">US20040030448A1</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2004-02-12" itemprop="publicationDate">2004-02-12</time>
# </td>
# <td itemprop="title">System, methods and apparatus for managing external computation and sensor resources applied to mobile robotic network
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/US20030006340A1/en">
# <span itemprop="publicationNumber">US20030006340A1</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2003-01-09" itemprop="publicationDate">2003-01-09</time>
# </td>
# <td itemprop="title">Aircraft
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/US9163909B2/en">
# <span itemprop="publicationNumber">US9163909B2</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2015-10-20" itemprop="publicationDate">2015-10-20</time>
# </td>
# <td itemprop="title">Unmanned multi-purpose ground vehicle with different levels of control
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/CN105151275A/en">
# <span itemprop="publicationNumber">CN105151275A</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2015-12-16" itemprop="publicationDate">2015-12-16</time>
# </td>
# <td itemprop="title">Elevon control system
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/AU2015205970B2/en">
# <span itemprop="publicationNumber">AU2015205970B2</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2019-05-09" itemprop="publicationDate">2019-05-09</time>
# </td>
# <td itemprop="title">Systems and methods countering an unmanned air vehicle
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/US20110186687A1/en">
# <span itemprop="publicationNumber">US20110186687A1</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2011-08-04" itemprop="publicationDate">2011-08-04</time>
# </td>
# <td itemprop="title">Unmanned gyrokite as self-powered airborne platform for electronic systems
#        </td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isScholar"/>
# <meta content="16677820269511825971" itemprop="scholarID"/>
# <a href="/scholar/16677820269511825971"><span itemprop="scholarAuthors">Barnes et al.</span></a>
# </td>
# <td>
# <time datetime="2005" itemprop="publicationDate">2005</time>
# </td>
# <td itemprop="title">ThrowBot: Design considerations for a man-portable throwable robot</td>
# </tr><tr itemprop="similarDocuments" itemscope="" repeat="">
# <td>
# <meta content="true" itemprop="isPatent"/>
# <a href="/patent/CN104583073A/en">
# <span itemprop="publicationNumber">CN104583073A</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
# </td>
# <td>
# <time datetime="2015-04-29" itemprop="publicationDate">2015-04-29</time>
# </td>
# <td itemprop="title">Self-tightening rotor
#        </td>
# </tr>
# </tbody>
# </table>
# </section>
# <section>
# <h2>Legal Events</h2>
# <table>
# <thead>
# <tr>
# <th>Date</th>
# <th>Code</th>
# <th>Title</th>
# <th>Description</th>
# </tr>
# </thead>
# <tbody>
# <tr itemprop="legalEvents" itemscope="" repeat="">
# <td><time datetime="2014-12-10" itemprop="date">2014-12-10</time></td>
# <td itemprop="code">AS</td>
# <td itemprop="title">Assignment</td>
# <td>
# <p itemprop="attributes" itemscope="" repeat="">
# <strong itemprop="label">Owner name</strong>:
#               <span itemprop="value">HER MAJESTY THE QUEEN IN RIGHT OF CANADA AS REPRES</span>
# </p>
# <p itemprop="attributes" itemscope="" repeat="">
# <strong itemprop="label">Free format text</strong>:
#               <span itemprop="value">ASSIGNMENT OF ASSIGNORS INTEREST;ASSIGNORS:ERICKSON, DAVID RYAN;CEH, MATTHEW WJ;ANDERSON, DALE;SIGNING DATES FROM 20130702 TO 20130709;REEL/FRAME:034465/0938</span>
# </p>
# </td>
# </tr>
# <tr itemprop="legalEvents" itemscope="" repeat="">
# <td><time datetime="2016-06-22" itemprop="date">2016-06-22</time></td>
# <td itemprop="code">STCF</td>
# <td itemprop="title">Information on status: patent grant</td>
# <td>
# <p itemprop="attributes" itemscope="" repeat="">
# <strong itemprop="label">Free format text</strong>:
#               <span itemprop="value">PATENTED CASE</span>
# </p>
# </td>
# </tr>
# </tbody>
# </table>
# </section>
# </article>
# </search-app>
# <script src="//www.gstatic.com/feedback/api.js" type="text/javascript"></script>
# <script async="" defer="" src="//www.google.com/insights/consumersurveys/async_survey?site=cxkjf7ipxgbnnjy6k35ezcvbbe"></script>
# </body>
# </html>
